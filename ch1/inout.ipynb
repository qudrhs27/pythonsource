# %% [markdown]
# ### 표준 입출력
#
# - 표준 입력 : 키보드 => input()
# - 표준 출력 : 모니터 => print()

# %%
num = input("숫자 입력")

# type(num)
# 사용자에게 숫자를 입력 받은 후 +10 한 결과를 출력
# try ~ except
if num.isdigit():
    num = int(num) + 10
    print(num)
else:
    print("숫자를 입력하세요")
# Out:
# 숫자를 입력하세요
